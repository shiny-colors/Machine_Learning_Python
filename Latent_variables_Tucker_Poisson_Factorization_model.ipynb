# %% [markdown]
# # Zero Truncated Tucker Poisson Factorization model
# ## 1. Poisson Factorization
# ### 定義
# Poisson Factorizationは確率的行列分解をの誤差項をポアソン分布に拡張したモデルで$i$をユーザー、$j$をアイテムとした場合、 非負値の応答変数$y_{i,j}$と$k次元$の潜在ベクトル$\theta_{ik}$と$\theta_{jk}$の間に以下のような関係があります。
#
# \begin{equation}
# y_{ij} \sim Poisson(\sum_{k}\theta_{ik}\theta_{jk})\tag{1}
# \end{equation}
#
# ### 生成過程
# Poisson Factorizationの生成過程は潜在ベクトルの事前分布にガンマ分布を仮定することでパラメータに非負制約にすることができます。
#
# 1. For each user $i$ and latent component $k$:
# \begin{equation}
# \theta_{ik} \sim Gamma(a_{user},b_{user})
# \end{equation}
#
# 2. For each item $j$ and latent component $k$:
# \begin{equation}
# \theta_{jk} \sim Gamma(a_{item},b_{item})
# \end{equation}
#
# 3. For each user $i$ and item $j$, sampling response:
# \begin{equation}
# y_{ij} \sim Poisson(\sum_{k}\theta_{ik}\theta_{jk})
# \end{equation}
#
# ### ポアソン分布の共役事前分布のおさらい
# ポアソン分布はガンマ分布が共役事前分布であることが知られています。ベイズモデルでのポアソン分布のパラメータの事後分布は以下の解析解が得られることが知られています。
#
# \begin{equation}
# \begin{split}
# p(\lambda|y) \propto p(\lambda)p(\bf y|\lambda) &= \frac{b^{a}}{\Gamma(a)}\lambda^{a-1}e^{-b\lambda} \times \frac{e^{-n\lambda}\lambda^{\sum_{i=1}^{n}y_{i}}}{\prod_{i=1}^{n}y_{i}!}\\
# &\propto \lambda^{n\bar{y}+a-1}e^{-(b+n)\lambda}
# \end{split}
# \end{equation}
#
# ただし、$p(\lambda)$はガンマ事前分布、$p(\bf y|\lambda)$はポアソン分布の尤度関数です。
# また$a$、$b$はガンマ分布のパラメータ、$\lambda$はポアソン分布のパラメータ、$\bf y$は$n$個の観測値です。
# 結局ポアソン-ガンマ分布の事後分布は
#
# \begin{equation}
# p(\lambda|y) \sim Gamma(n\bar{y}+a-1,b+n)\tag{2}
# \end{equation}
#
# となります。(1)のパラメータは(2)を利用して事後分布を推定することができます。
#
# ## 2. シミュレーションデータの生成
# ### Tucker Decomposition
# $\lambda$はより一般的な行列分解の構造であるTucker Decompositionで定式化します。
#
# \begin{equation}
# \lambda_{ijk} = \sum_{r=1}^{R}\sum_{s=1}^{S}\sum_{t=1}^{T}\omega_{rst}\theta_{ir}\theta_{js}\theta_{kt} \tag{3}
# \end{equation}
#
# ただし、$R$、$S$、$T$はそれぞれのモードの潜在変数のベクトル数で、$\theta$に加え、コアテンソル$\omega$もガンマ分布に従いパラメータが生成されます。そして\$lambda\の期待値構造からポアソン分布に従いデータが生成されます。
#
# \begin{equation}
# y_{ijk} \sim Poisson(\lambda_{ijk})
# \end{equation}
#
# 以下のコードでシミュレーションデータの生成を行います。

# %%
# ライブラリの読み込み
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
import numpy.matlib
import scipy.linalg
import itertools
import scipy
from scipy import stats
from scipy import special
from scipy import sparse
from numpy.random import *

np.random.seed(98537)

# %%
# 多項分布の乱数を生成する関数
def rmnom(pr, n, k, no):
    z_id = np.argmax((np.cumsum(pr, axis=1) >= np.random.uniform(0, 1, n)[:, np.newaxis]), axis=1)
    Z = sparse.coo_matrix((np.repeat(1, n), (no, np.array(z_id))), shape=(n, k))   #スパース行列の設定
    return Z

# 切断ポアソン分布の乱数を生成するための関数
def rtpois(value, n, lower):
    k = np.repeat(lower, n)
    z = np.repeat(1, n)
    mu = np.exp(-value)
    t = (mu / (1 - mu)) * value
    s = t.copy()
    u = np.random.uniform(0, 1, n)

    while True:
        z = s < u
        index = np.where(z==True)[0]
        if index.shape[0]==0:
            break    
        k[index] = k[index] + z[index]
        t[index] = t[index] * value[index] / k[index]
        s[index] = s[index] + t[index]
    return k

# %% [markdown]
# ### a. 入力データの生成

# %%
##データの設定
type_n = 3   #モード数
k1 = 12
k2 = 10
k3 = 7
hh = 5000   #モード1のサンプル数
item = 3000   #モード2のサンプル数
context = 100   #モード3のサンプル数
Lambda = np.random.gamma(100.0, 1/0.2, hh)
pt0 = np.random.poisson(Lambda, hh)   #モードあたりのレコード数
N0 = np.sum(pt0)
vec_k1 = np.repeat(1, k1); vec_k2 = np.repeat(1, k2); vec_k3 = np.repeat(1, k3)

# %%
##IDとインデックスを作成
#IDの作成
d_id0 = np.repeat(np.arange(hh), pt0)
pt_id0 = np.array(list(itertools.chain(*[np.array(range(pt0[i]), dtype="int") for i in range(hh)])))

# インデックスの設定
index = np.array(range(N0))
d_list0 = [i for i in range(hh)]
for i in range(hh):
    d_list0[i] = index[d_id0==i]

# %%
##アイテムの割当を生成
#トピック割当を生成
topic = 25
phi1 = np.random.dirichlet(np.repeat(0.5, item), topic)
theta1 = np.random.dirichlet(np.repeat(0.5, topic), hh)
z1 = np.dot(np.array([np.random.multinomial(1, theta1[i, :], 1) for i in range(hh)]).reshape(hh, topic), range(topic))

#多項分布からアイテムを生成
item_id0 = np.zeros(N0, dtype='int')
for i in range(hh):
    if i%1000==0:
        print(i)
    item_id0[d_list0[i]] = np.dot(np.random.multinomial(1, phi1[z1[i], :], pt0[i]), range(item))
item_dt0 = sparse.coo_matrix((np.repeat(1, N0), (item_id0, range(N0))), shape=(item, N0)).tocsr()   #スパース行列の設定
item_n0 = np.array(np.sum(item_dt0, axis=1)).reshape(-1)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000

# %%
##コンテキストの割当を生成
#トピック割当を生成
topic = 15
phi2 = np.random.dirichlet(np.repeat(0.25, context), topic)
theta2 = np.random.dirichlet(np.repeat(0.25, topic), hh)
z2 = np.dot(np.array([np.random.multinomial(1, theta2[i, :], 1) for i in range(hh)]).reshape(hh, topic), range(topic))

#多項分布からアイテムを生成
context_id0 = np.zeros(N0, dtype='int')
for i in range(hh):
    if i%1000==0:
        print(i)
    context_id0[d_list0[i]] = np.dot(np.random.multinomial(1, phi2[z2[i], :], pt0[i]), range(context))
context_dt0 = sparse.coo_matrix((np.repeat(1, N0), (context_id0, range(N0))), shape=(context, N0)).tocsr()   #スパース行列の設定
context_n0 = np.array(np.sum(context_dt0, axis=1)).reshape(-1)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000

# %% [markdown]
# ### b. 学習データの応答変数の生成
# 実データの応答変数$y$は欠損で$y > 0$の値しか取得できないことが多いため、0以外の値を学習データに用いる。
# もし、$y = 0$が含まれているデータを欠損として扱わずに学習データに加えるとパラメータの推定値に偏りが生じてしまいます。

# %%
rp = 0
while True:
    rp = rp + 1
    
    ##パラメータを生成
    #ガンマ分布のパラメータ
    alpha_u = 0.2; beta_u = 0.7
    alpha_v = 0.2; beta_v = 0.7
    alpha_c = 0.15; beta_c = 0.75
    alpha_r = 0.1; beta_r = 1.0
    
    #ガンマ分布から行列分解のパラメータを生成
    theta_u = np.random.gamma(alpha_u, 1/beta_u, hh*k1).reshape(hh, k1)
    theta_v = np.random.gamma(alpha_v, 1/beta_v, item*k2).reshape(item, k2)
    theta_c = np.random.gamma(alpha_c, 1/beta_c, context*k3).reshape(context, k3)
    omega = np.random.gamma(alpha_r, 1/beta_r, k1*k2*k3).reshape(k1, k2, k3)
    thetat_u = theta_u.copy(); thetat_v = theta_v.copy(); thetat_c = theta_c.copy(); omegat = omega.copy()

    ##ポアソン分布から応答変数を生成
    #タッカー分解の期待値
    mu = np.repeat(0.0, N0)
    theta_vec2 = theta_v[item_id0, ]
    theta_vec3 = theta_c[context_id0, ]
    for j in range(k3):
        mu += np.dot(np.dot(theta_u, omega[:, :, j])[d_id0, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)

    #応答変数を生成
    y0 = np.random.poisson(mu, N0)
    
    #break条件
    print(np.array([rp, np.max(y0), np.sum(y0 > 0)]))
    if (np.max(y0) < 300) & (np.max(y0) > 75):
        break
# Out:
# [      1     592 1127775]
# [      2     603 1008645]
# [      3     358 1142082]
# [     4    422 952209]
# [      5     478 1081024]
# [      6     391 1009523]
# [     7    250 989914]

# %%
##学習対象データのみを取得
#y > 0以上の応答変数のみ取得
index_y = np.array(np.where(y0 > 0)[0], dtype="int")
y1 = y0[index_y]
d_id1 = d_id0[index_y]
item_id1 = item_id0[index_y]
context_id1 = context_id0[index_y]
hhpt = index_y.shape[0]

#インデックスを作成
d_list1 = [i for i in range(hh)]
item_list1 = [i for i in range(hh)]
context_list1 = [i for i in range(hh)]
pt1 = np.repeat(0, hh)
item_n1 = np.repeat(0, item)
context_n1 = np.repeat(0, context)
for i in range(hh):
    d_list1[i] = np.array(np.where(d_id1==i)[0], dtype="int")
    pt1[i] = d_list1[i].shape[0]
for i in range(item):
    item_list1[i] = np.array(np.where(item_id1==i)[0], dtype="int")
    item_n1[i] = item_list1[i].shape[0]
for i in range(context):
    context_list1[i] = np.array(np.where(context_id1==i)[0], dtype="int")
    context_n1[i] = context_list1[i].shape[0]
del y0, d_id0, item_id0, context_id0, d_list0

# %%
#生成したデータを可視化
dt = [y1, mu]
fig_range = np.append(np.array([np.min(y1), np.min(mu)]), 
                      np.array([np.max(y1), np.max(mu)])).reshape(2, len(dt))
colorlist = ["r", "g", "b", "c", "m", "y", "k", "w"]
legend = ["応答変数の分布", "期待値の分布"]
fig = plt.figure(figsize=(10.0, 3.0))
for j in range(len(dt)):
    ax = fig.add_subplot(1, 2, j+1)
    ax.hist(dt[j],  bins=25, range=(fig_range[0, j], fig_range[1, j]), color=colorlist[j])
    plt.title(legend[j], fontsize=12.5)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### c. テストデータの応答変数の生成
# b.で生成した学習データは$y > 0$のみが含まれています。テストデータで生成するデータは$y = 0$のデータと$y > 0$の両方が含まれていますが、
# しかし実データでは欠損して、$y = 0$の扱いになっているため、学習データで推定したパラメータを用いてテストデータの欠損を予測します。

# %%
##モードごとのIDを作成
#データの設定
pt0 = np.random.poisson(Lambda/2.0, hh)   #ユーザーあたりのレコード数
N0 = np.sum(pt0)

#ユーザーIDを作成
d_id0 = np.repeat(np.arange(hh), pt0)
d_list0 = [i for i in range(hh)]
for i in range(hh):
    d_list0[i] = np.array(np.where(d_id0==i)[0], dtype="int")

#アイテムIDを作成
item_id0 = np.zeros(N0, dtype='int')
for i in range(hh):
    item_id0[d_list0[i]] = np.dot(np.random.multinomial(1, phi1[z1[i], :], pt0[i]), range(item))
    
#コンテキストIDを作成
context_id0 = np.zeros(N0, dtype='int')
for i in range(hh):
    context_id0[d_list0[i]] = np.dot(np.random.multinomial(1, phi2[z2[i], :], pt0[i]), range(context))
    
#学習データと重複があるIDを除く
id1 = pd.DataFrame({"d_id": d_id1, "item_id": item_id1, "context_id": context_id1, "flag": 1})
id2 = pd.DataFrame({"d_id": d_id0, "item_id": item_id0, "context_id": context_id0, "flag": 2})
joint_id = pd.concat((id1, id2), axis=0)
index_target = np.array(np.where((joint_id.iloc[:, :type_n].duplicated()==False) & (joint_id["flag"]==2))[0], dtype="int")
d_id2 = np.array(joint_id["d_id"].iloc[index_target])
item_id2 = np.array(joint_id["item_id"].iloc[index_target])
context_id2 = np.array(joint_id["context_id"].iloc[index_target])
N = index_target.shape[0]

# %%
##ポアソン分布から応答変数を生成
#タッカー分解の期待値
mu = np.repeat(0.0, N)
theta_vec2 = thetat_v[item_id2, ]
theta_vec3 = thetat_c[context_id2, ]
for j in range(k3):
    mu += np.dot(np.dot(thetat_u, omegat[:, :, j])[d_id2, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)

#応答変数を生成
y2 = np.random.poisson(mu, N)
y_vec2 = y2[:, np.newaxis]

# %% [markdown]
# ## 3. ギブスサンプリングによるPoisson Factorizationの推定
# ### 概要
# ### 特徴ベクトルのサンプリング
# 特徴ベクトル$\bf \theta$は事前分布がガンマ分布、尤度関数がポアソン分布なので、共役性があり事後分布はガンマ分布に従います。
# しかし(3)の形式とはなりません。しかしTucker Decompositionのパラメータと期待値が全て非負の値を取るという性質を利用して特徴ベクトルの事後分布を計算することができます。
# そのために以下の補助変数を導入します。
# Tucker Decompositionの期待値は
#
# \begin{equation}
# \lambda_{ijk} = \sum_{r=1}^{R}\sum_{s=1}^{S}\sum_{t=1}^{T}\omega_{rst}\theta_{ir}\theta_{js}\theta_{kt}
# \end{equation}
#
# となり、$\theta_{ir}$の補助変数$\kappa_{ijk}^{r}$は
#
# \begin{equation}
# \kappa_{ijk}^{r} \rm = \frac{\sum_{s=1}^{S}\sum_{t=1}^{T}\omega_{rst}\theta_{ir}\theta_{js}\theta_{kt}}{\lambda_{ijk}} \tag{4}
# \end{equation}
#
# です。$\sum_{r=1}^{R}\kappa_{ijk}^{r}=1$を満たし、$\lambda_{ijk}$のうち$\theta_{ir}$に関係する部分の貢献分を意味しています。
# この補助変数を利用してガンマ分布の事後分布の尺度パラメータは
#
# \begin{equation}
# \dot{\alpha}_{i}^{r} = \sum_{jk\in J_{i}K_{i}} \kappa_{ijk}^{r} y_{ijk} + \alpha_{u} \tag{5}
# \end{equation}
#
# となり、ただし$jk\in J_{i}K_{i}$はユーザー$i$に関連するレコードの集合を$\alpha_{u}$はハイパーパラメータを表します。
# また、形状パラメータは(4)から$\theta_{ik}$に関連する部分を取り除いた
#
# \begin{equation}
# \dot{\beta}_{i}^{r} = \sum_{s=1}^{S}\sum_{t=1}^{T}\omega_{rst}\theta_{js}\theta_{kt} + \beta_{u} \tag{6}
# \end{equation}
#
# となり、結局事後分布は(5)、(6)より
#
# \begin{equation}
# p(\theta_{ir}|y, \omega_{rst}, \theta_{js}, \theta_{kt}) \sim Gamma(\dot{\alpha}_{i}^{r}, \dot{\beta}_{i}^{r}) \tag{7}
# \end{equation}
#
# となります。$\theta_{js}$、$\theta_{kt}$も同じように事後分布を計算することができます。
#
# ### コアテンソルのサンプリング
# コアテンソル$\omega_{rst}$の事後分布はテンソルのセルごとに補助変数を計算することで推定することができます。
#
# \begin{equation}
# \kappa_{rst} = \frac{\sum_{i=1}^{I}\sum_{j=1}^{J}\sum_{k=1}^{K}\omega_{rst}\theta_{ir}\theta_{js}\theta_{kt}}{\sum_{i=1}^{I}\sum_{j=1}^{J}\sum_{k=1}^{K}\lambda_{ijk}} \tag{8}
# \end{equation}
#
# よってガンマ分布の事後分布の形状パラメータは
#
# \begin{equation}
# \dot{\alpha_{rst}} = \kappa_{rst} \sum_{i}^{I}\sum_{j}^{J}\sum_{k}^{K} y_{ijk} + \alpha_{tensor} \tag{9}
# \end{equation}
#
# また、形状パラメータは$\omega_{rst}$に関連する部分を取り除いた
#
# \begin{equation}
# \dot{\beta_{rst}} = \sum_{i=1}^{I}\sum_{j=1}^{J}\sum_{k=1}^{K}\theta_{ir}\theta_{js}\theta_{kt} + \beta_{tensor} \tag{10}
# \end{equation}
#
# となり、結局事後分布は(9)、(10)より
#
# \begin{equation}
# p(\omega_{rst}|y, \theta_{ir}, \theta_{js}, \theta_{kt}) \sim Gamma(\dot{\alpha}_{rst}, \dot{\beta}_{rst}) \tag{11}
# \end{equation}
#
# となります。
#
# ### 潜在変数zのサンプリング
# 観測変数$y_{ijk}$は$y > 0$の値しか観測されていないため、観測変数$y_{ijk}$のまま推定するとパラメータ推定値にバイアスが生じます。そこで$y > 0$が観測されるかどうかの潜在変数zを導入することで新しい観測変数$\dot{y_{ijk}}$でパラメータを推定します。
# $y > 0$が観測される確率は$y$がポアソン分布なので、
#
# \begin{equation}
# P_{ijk} = 1 - \exp(\lambda_{ijk}) \tag{12}
# \end{equation}
#
# パラメータ$P_{ijk}$のベルヌーイ分布から潜在変数zをサンプリング
#
# \begin{equation}
# z_{ijk} \sim Bernoulli(P_{ijk})
# \end{equation}
#
# 新しい観測変数$\dot{y_{ijk}}$を$z_{ijk}$と$y_{ijk}$の重み付き変数として以下のように定義します。
#
# \begin{equation}
# \dot{y_{ijk}} = z_{ijk}y_{ijk}
# \end{equation}
#
# この新しい観測変数$\dot{y_{ijk}}$を用いることでシミュレーションデータについて精度を実験してみるとテストデータの対数尤度が大幅に改善されることが確認されました。
#
# ### 補助変数を用いたさまざまな推定
# この補助変数を用いた事後分布の推定には以下のような形式の$\lambda$でも容易に解くことができます。
#
# \begin{equation}
# \lambda_{ijk} = \sum_{r=1}^{R}\theta_{ir}\theta_{jr} + \sum_{r=1}^{R}\theta_{ir}\theta_{cr} +\sum_{r=1}^{R}\theta_{jr}\theta_{cr} + \sum_{r=1}^{R}\theta_{ir}\theta_{jr}\theta_{kr}
# \end{equation}
#
# \begin{equation}
# \lambda_{ij} = \sum_{t\prime < t}\exp\bigl(-\gamma(t-t\prime)\bigr)\sum_{r=1}^{R}\theta_{ir}\theta_{jr}
# \end{equation}
#
# \begin{equation}
# \lambda_{i} = \bf x_{i}\ \bf \theta
# \end{equation}
#
# \begin{equation}
# \lambda_{i} = \theta_{i1} + \theta_{j} + \bf x_{i}\ \bf \theta_{i2}
# \end{equation}
#
# ただし一般化線形モデルで用いられる以下の形式は解くことができません。
#
# \begin{equation}
# \lambda_{i} = \exp(\bf x_{i}\ \bf \theta)
# \end{equation}

# %% [markdown]
# ### c. アルゴリズムの設定

# %%
####マルコフ連鎖モンテカルロ法でPoisson Tucker Decompositionを推定####
##アルゴリズムと定数の設定
#アルゴリズムの設定
R = 1000
keep = 2
burnin = int(250/keep)
iter = 0
disp = 10
L = 3

#定数の設定
y_vec1 = y1[:, np.newaxis]
y_vec2 = y2[:, np.newaxis]
lfactorial_y1 = scipy.special.gammaln(y1 + 1)
lfactorial_y2 = scipy.special.gammaln(y2 + 1)

# %%
#事前分布の設定
alpha1 = 0.25; beta1 = 0.5
alpha2 = 0.25; beta2 = 0.5
alpha3 = 0.25; beta3 = 0.5
alpha4 = 0.25; beta4 = 1.0

# %%
##パラメータの初期値
#特徴行列の初期値
theta_u = np.random.gamma(0.25, 1/1.0, hh*k1).reshape(hh, k1)
theta_v = np.random.gamma(0.25, 1/1.0, item*k2).reshape(item, k2)
theta_c = np.random.gamma(0.25, 1/1.0, context*k3).reshape(context, k3)
omega = np.random.gamma(0.1, 1/1.0, k1*k2*k3).reshape(k1, k2, k3)

#期待値の初期値
mu = np.repeat(0.0, hhpt)
theta_vec2 = theta_v[item_id1, ]
theta_vec3 = theta_c[context_id1, ]
for j in range(k3):
    mu += np.dot(np.dot(theta_u, omega[:, :, j])[d_id1, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)

# %%
##サンプリング結果の格納用配列
THETA_U = np.zeros((hh, k1, int(R/keep)))
THETA_V = np.zeros((item, k2, int(R/keep)))
THETA_C = np.zeros((context, k3, int(R/keep)))
OMEGA = np.zeros((k1, k2, k3, int(R/keep)))

# %%
##学習データに対する対数尤度の基準値
#1パラメータモデルでの対数尤度
Lambda = np.mean(y1)
LLst1 = np.sum(scipy.stats.poisson.logpmf(y1, Lambda))

#真値での対数尤度
mu = np.repeat(0.0, hhpt)
theta_vec2 = thetat_v[item_id1, ]
theta_vec3 = thetat_c[context_id1, ]
for j in range(k3):
    mu += np.dot(np.dot(thetat_u, omegat[:, :, j])[d_id1, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)
LLbest1 = np.sum(y1*np.log(mu) - mu - lfactorial_y1)
print(np.round(np.array([LLst1, LLbest1]), 1))

##テストデータに対する対数尤度の基準値
#1パラメータモデルでの対数尤度
Lambda = np.mean(y1)
LLst2 = np.sum(scipy.stats.poisson.logpmf(y2, Lambda))

#テストデータに対する真値での対数尤度
mu = np.repeat(0.0, N)
theta_vec2 = thetat_v[item_id2, ]
theta_vec3 = thetat_c[context_id2, ]
for j in range(k3):
    mu += np.dot(np.dot(thetat_u, omegat[:, :, j])[d_id2, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)
LLbest2 = np.sum(y2*np.log(mu) - mu - lfactorial_y2)
print(np.round(np.array([LLst2, LLbest2]), 1))
# Out:
# [-2662404.9 -1813264.8]
# [-3495487.5 -1110239. ]

# %% [markdown]
# ### d. 潜在変数zのある場合の推定

# %%
####ギブスサンプリングでパラメータをサンプリング####
for rp in range(R):
    
    ##潜在変数zをサンプリング
    #潜在変数zの割当確率
    mu_dt = np.zeros((hhpt, k1)); lambda_h = np.zeros((hhpt, k1))
    theta_vec1 = theta_u[d_id1, ]; theta_vec2 = theta_v[item_id1, ]; theta_vec3 = theta_c[context_id1, ]
    for j in range(k1):
        lambda_dt = np.dot(theta_v, omega[j, :, :])[item_id1, ] * theta_vec3
        lambda_h[:, j] = np.dot(lambda_dt, vec_k3)
        mu_dt[:, j] = np.dot(lambda_dt * theta_vec1[:, j][:, np.newaxis], vec_k3)
    mu = np.dot(mu_dt, vec_k1)
    Prob = 1 - np.exp(-mu)

    #潜在変数zから新しい変数を作成
    z = np.random.binomial(1, Prob, hhpt)
    y_new1 = z * y1
    y_vec1 = y_new1[:, np.newaxis]
    
    
    ##ユーザーの特徴行列をサンプリング
    #補助変数lambdaを更新
    Lambda = mu_dt / mu[:, np.newaxis]

    #事後分布のパラメータ
    lambda_y = Lambda * y_vec1
    W1 = np.zeros((hh, k1)); W2 = np.zeros((hh, k1))
    for i in range(hh):
        index = d_list1[i]
        W1[i, ] = np.sum(lambda_y[index, ], axis=0)
        W2[i, ] = np.sum(lambda_h[index, ], axis=0)
    W1 = W1 + alpha1; W2 = W2 + beta1

    #ガンマ分布からパラメータをサンプリング
    theta_u = np.random.gamma(W1, 1/W2)

    
    ##アイテムの特徴行列をサンプリング
    #補助変数lambdaを更新
    mu_dt = np.zeros((hhpt, k2)); lambda_h = np.zeros((hhpt, k2))
    theta_vec1 = theta_u[d_id1, ]
    for j in range(k2):
        lambda_dt = np.dot(theta_u, omega[:, j, :])[d_id1, ] * theta_vec3
        lambda_h[:, j] = np.dot(lambda_dt, vec_k3)
        mu_dt[:, j] = np.dot(lambda_dt * theta_vec2[:, j][:, np.newaxis], vec_k3)
    mu = np.dot(mu_dt, vec_k2)
    Lambda = mu_dt / mu[:, np.newaxis]

    #事後分布のパラメータ
    lambda_y = Lambda * y_vec1
    H1 = np.zeros((item, k2)); H2 = np.zeros((item, k2))
    for j in range(item):
        index = item_list1[j]
        H1[j, ] = np.sum(lambda_y[index, ], axis=0)
        H2[j, ] = np.sum(lambda_h[index, ], axis=0)
    H1 = H1 + alpha1; H2 = H2 + beta2

    #ガンマ分布からパラメータをサンプリング
    theta_v = np.random.gamma(H1, 1/H2)

    
    ##コンテキストの特徴行列をサンプリング
    #補助変数lambdaを更新
    mu_dt = np.zeros((hhpt, k3)); lambda_h = np.zeros((hhpt, k3))
    theta_vec2 = theta_v[item_id1, ]
    for j in range(k3):
        lambda_dt = np.dot(theta_u, omega[:, :, j])[d_id1, ] * theta_vec2
        lambda_h[:, j] = np.dot(lambda_dt, vec_k2)
        mu_dt[:, j] = np.dot(lambda_dt * theta_vec3[:, j][:, np.newaxis], vec_k2)
    mu = np.dot(mu_dt, vec_k3)
    Lambda = mu_dt / mu[:, np.newaxis]

    #事後分布のパラメータ
    lambda_y = Lambda * y_vec1
    C1 = np.zeros((context, k3)); C2 = np.zeros((context, k3))
    for j in range(context):
        index = context_list1[j]
        C1[j, ] = np.sum(lambda_y[index, ], axis=0)
        C2[j, ] = np.sum(lambda_h[index, ], axis=0)
    C1 = C1 + alpha3; C2 = C2 + beta3

    #ガンマ分布からパラメータをサンプリング
    theta_c = np.random.gamma(C1, 1/C2)

    
    ##ガンマ分布よりomegaをサンプリング
    #補助変数lambdaを更新
    mu_block = np.zeros((k1, k2, k3))
    theta_dt12 = [j for j in range(k1)]
    for j1 in range(k3):
        theta_dt3 = theta_vec3[:, j1][:, np.newaxis]
        for j2 in range(k1):
            if j1==0:
                theta_dt12[j2] = theta_vec1[:, j2][:, np.newaxis] * theta_vec2
            mu_dt = theta_dt12[j2] * theta_dt3
            mu_block[j2, :, j1] = np.sum(mu_dt, axis=0)
    omega_block = omega * mu_block
    Lambda = omega_block / np.sum(omega_block)

    #ガンマ分布からパラメータをサンプリング
    omega1 = Lambda * np.sum(y_new1) + alpha4
    omega2 = mu_block + beta4
    omega = np.random.gamma(omega1, 1/omega2)
    

    ##サンプリング結果の格納と表示
    if rp%keep==0:
        mkeep = int(rp/keep)
        THETA_U[:, :, mkeep] = theta_u
        THETA_V[:, :, mkeep] = theta_v
        THETA_C[:, :, mkeep] = theta_c
        OMEGA[:, :, :, mkeep] = omega
        
    if rp%disp==0:
        #学習データに対する対数尤度
        mu = np.repeat(0.0, hhpt)
        theta_vec2 = theta_v[item_id1, ]
        theta_vec3 = theta_c[context_id1, ]
        for j in range(k3):
            mu += np.dot(np.dot(theta_u, omega[:, :, j])[d_id1, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)
        LL1 = np.sum(y1*np.log(mu) - mu - lfactorial_y1)

        #テストデータに対する対数尤度
        mu = np.repeat(0.0, N)
        theta_vec2 = theta_v[item_id2, ]
        theta_vec3 = theta_c[context_id2, ]
        for j in range(k3):
            mu += np.dot(np.dot(theta_u, omega[:, :, j])[d_id2, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)
        LL2 = np.sum(y2*np.log(mu) - mu - lfactorial_y2)

        #サンプリング結果を表示
        print(rp)
        print(["学習データの対数尤度:", np.round(LL1, 1), "学習データの真値の対数尤度:", np.round(LLbest1, 1)])
        print(["テストデータの対数尤度:", np.round(LL2, 1), "テストデータの真値の対数尤度:", np.round(LLbest2, 1)])
# Out:
# 0
# ['学習データの対数尤度:', -4095658.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -2390350.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 10
# ['学習データの対数尤度:', -2130280.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1458183.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 20
# ['学習データの対数尤度:', -2078199.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1445794.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 30
# ['学習データの対数尤度:', -2054270.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1439867.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 40
# ['学習データの対数尤度:', -2038390.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1436677.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 50
# ['学習データの対数尤度:', -2024396.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1432698.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 60
# ['学習データの対数尤度:', -2011873.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1429008.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 70
# ['学習データの対数尤度:', -1999427.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1425166.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 80
# ['学習データの対数尤度:', -1991563.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1418918.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 90
# ['学習データの対数尤度:', -1983867.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1410357.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 100
# ['学習データの対数尤度:', -1976209.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1405717.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 110
# ['学習データの対数尤度:', -1967212.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1401633.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 120
# ['学習データの対数尤度:', -1962995.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1393880.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 130
# ['学習データの対数尤度:', -1952450.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1387847.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 140
# ['学習データの対数尤度:', -1950068.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1379691.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 150
# ['学習データの対数尤度:', -1943208.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1375342.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 160
# ['学習データの対数尤度:', -1939925.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1368858.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 170
# ['学習データの対数尤度:', -1935076.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1364985.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 180
# ['学習データの対数尤度:', -1931872.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1360281.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 190
# ['学習データの対数尤度:', -1930834.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1354776.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 200
# ['学習データの対数尤度:', -1927070.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1350635.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 210
# ['学習データの対数尤度:', -1924173.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1348984.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 220
# ['学習データの対数尤度:', -1922663.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1345233.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 230
# ['学習データの対数尤度:', -1918281.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1342675.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 240
# ['学習データの対数尤度:', -1913948.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1339212.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 250
# ['学習データの対数尤度:', -1911328.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1335559.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 260
# ['学習データの対数尤度:', -1911317.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1332372.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 270
# ['学習データの対数尤度:', -1906520.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1328627.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 280
# ['学習データの対数尤度:', -1904251.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1324910.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 290
# ['学習データの対数尤度:', -1903843.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1321769.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 300
# ['学習データの対数尤度:', -1900277.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1318651.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 310
# ['学習データの対数尤度:', -1899025.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1314558.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 320
# ['学習データの対数尤度:', -1893160.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1312054.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 330
# ['学習データの対数尤度:', -1893537.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1309805.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 340
# ['学習データの対数尤度:', -1890685.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1309401.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 350
# ['学習データの対数尤度:', -1889770.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1305743.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 360
# ['学習データの対数尤度:', -1888185.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1303586.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 370
# ['学習データの対数尤度:', -1889232.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1300698.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 380
# ['学習データの対数尤度:', -1886856.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1299301.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 390
# ['学習データの対数尤度:', -1887870.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1297868.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 400
# ['学習データの対数尤度:', -1887171.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1296544.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 410
# ['学習データの対数尤度:', -1882875.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1296454.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 420
# ['学習データの対数尤度:', -1880574.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1297038.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 430
# ['学習データの対数尤度:', -1881671.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1294085.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 440
# ['学習データの対数尤度:', -1879452.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1292217.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 450
# ['学習データの対数尤度:', -1878284.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1292350.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 460
# ['学習データの対数尤度:', -1878895.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1290716.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 470
# ['学習データの対数尤度:', -1877457.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1291463.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 480
# ['学習データの対数尤度:', -1876057.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1289565.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 490
# ['学習データの対数尤度:', -1877000.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1289213.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 500
# ['学習データの対数尤度:', -1875279.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1288642.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 510
# ['学習データの対数尤度:', -1874896.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1288789.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 520
# ['学習データの対数尤度:', -1875443.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1287471.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 530
# ['学習データの対数尤度:', -1873480.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1287374.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 540
# ['学習データの対数尤度:', -1874395.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1286505.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 550
# ['学習データの対数尤度:', -1872999.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1286172.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 560
# ['学習データの対数尤度:', -1873084.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285907.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 570
# ['学習データの対数尤度:', -1873602.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285933.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 580
# ['学習データの対数尤度:', -1873295.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285069.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 590
# ['学習データの対数尤度:', -1873563.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285404.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 600
# ['学習データの対数尤度:', -1872960.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285348.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 610
# ['学習データの対数尤度:', -1872977.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284900.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 620
# ['学習データの対数尤度:', -1872185.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285049.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 630
# ['学習データの対数尤度:', -1871538.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284575.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 640
# ['学習データの対数尤度:', -1872173.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1286070.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 650
# ['学習データの対数尤度:', -1873388.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284819.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 660
# ['学習データの対数尤度:', -1875424.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284176.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 670
# ['学習データの対数尤度:', -1872757.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1282813.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 680
# ['学習データの対数尤度:', -1876274.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284868.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 690
# ['学習データの対数尤度:', -1874726.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284234.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 700
# ['学習データの対数尤度:', -1871190.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283777.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 710
# ['学習データの対数尤度:', -1869805.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285246.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 720
# ['学習データの対数尤度:', -1874073.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284645.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 730
# ['学習データの対数尤度:', -1872512.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284882.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 740
# ['学習データの対数尤度:', -1873188.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284200.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 750
# ['学習データの対数尤度:', -1873911.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284484.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 760
# ['学習データの対数尤度:', -1872699.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284570.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 770
# ['学習データの対数尤度:', -1871268.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283728.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 780
# ['学習データの対数尤度:', -1871301.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284164.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 790
# ['学習データの対数尤度:', -1873123.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283206.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 800
# ['学習データの対数尤度:', -1870005.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284319.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 810
# ['学習データの対数尤度:', -1871873.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285030.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 820
# ['学習データの対数尤度:', -1870977.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284550.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 830
# ['学習データの対数尤度:', -1872246.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284083.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 840
# ['学習データの対数尤度:', -1870682.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284462.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 850
# ['学習データの対数尤度:', -1869569.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285154.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 860
# ['学習データの対数尤度:', -1871186.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284052.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 870
# ['学習データの対数尤度:', -1870692.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285122.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 880
# ['学習データの対数尤度:', -1870905.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284454.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 890
# ['学習データの対数尤度:', -1872187.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283945.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 900
# ['学習データの対数尤度:', -1870621.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283969.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 910
# ['学習データの対数尤度:', -1871383.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284218.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 920
# ['学習データの対数尤度:', -1871710.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283609.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 930
# ['学習データの対数尤度:', -1872197.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283747.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 940
# ['学習データの対数尤度:', -1872487.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283714.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 950
# ['学習データの対数尤度:', -1871423.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1285605.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 960
# ['学習データの対数尤度:', -1872345.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283731.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 970
# ['学習データの対数尤度:', -1871061.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284163.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 980
# ['学習データの対数尤度:', -1872114.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1283351.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 990
# ['学習データの対数尤度:', -1870513.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1284186.2, 'テストデータの真値の対数尤度:', -1110239.0]

# %% [markdown]
# ### d. 潜在変数zのない場合の推定

# %%
##パラメータの初期値
#特徴行列の初期値
theta_u = np.random.gamma(0.25, 1/1.0, hh*k1).reshape(hh, k1)
theta_v = np.random.gamma(0.25, 1/1.0, item*k2).reshape(item, k2)
theta_c = np.random.gamma(0.25, 1/1.0, context*k3).reshape(context, k3)
omega = np.random.gamma(0.1, 1/1.0, k1*k2*k3).reshape(k1, k2, k3)

#期待値の初期値
mu = np.repeat(0.0, hhpt)
theta_vec2 = theta_v[item_id1, ]
theta_vec3 = theta_c[context_id1, ]
for j in range(k3):
    mu += np.dot(np.dot(theta_u, omega[:, :, j])[d_id1, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)
    
#定数の設定
y_vec1 = y1[:, np.newaxis]
y_vec2 = y2[:, np.newaxis]
lfactorial_y1 = scipy.special.gammaln(y1 + 1)
lfactorial_y2 = scipy.special.gammaln(y2 + 1)

# %%
####ギブスサンプリングでパラメータをサンプリング####
for rp in range(R):

    ##ユーザーの特徴行列をサンプリング
    #補助変数lambdaを更新
    mu_dt = np.zeros((hhpt, k1)); lambda_h = np.zeros((hhpt, k1))
    theta_vec1 = theta_u[d_id1, ]; theta_vec2 = theta_v[item_id1, ]; theta_vec3 = theta_c[context_id1, ]
    for j in range(k1):
        lambda_dt = np.dot(theta_v, omega[j, :, :])[item_id1, ] * theta_vec3
        lambda_h[:, j] = np.dot(lambda_dt, vec_k3)
        mu_dt[:, j] = np.dot(lambda_dt * theta_vec1[:, j][:, np.newaxis], vec_k3)
    mu = np.dot(mu_dt, vec_k1)
    Lambda = mu_dt / mu[:, np.newaxis]

    #事後分布のパラメータ
    lambda_y = Lambda * y_vec1
    W1 = np.zeros((hh, k1)); W2 = np.zeros((hh, k1))
    for i in range(hh):
        index = d_list1[i]
        W1[i, ] = np.sum(lambda_y[index, ], axis=0)
        W2[i, ] = np.sum(lambda_h[index, ], axis=0)
    W1 = W1 + alpha1; W2 = W2 + beta1

    #ガンマ分布からパラメータをサンプリング
    theta_u = np.random.gamma(W1, 1/W2)

    
    ##アイテムの特徴行列をサンプリング
    #補助変数lambdaを更新
    mu_dt = np.zeros((hhpt, k2)); lambda_h = np.zeros((hhpt, k2))
    theta_vec1 = theta_u[d_id1, ]
    for j in range(k2):
        lambda_dt = np.dot(theta_u, omega[:, j, :])[d_id1, ] * theta_vec3
        lambda_h[:, j] = np.dot(lambda_dt, vec_k3)
        mu_dt[:, j] = np.dot(lambda_dt * theta_vec2[:, j][:, np.newaxis], vec_k3)
    mu = np.dot(mu_dt, vec_k2)
    Lambda = mu_dt / mu[:, np.newaxis]

    #事後分布のパラメータ
    lambda_y = Lambda * y_vec1
    H1 = np.zeros((item, k2)); H2 = np.zeros((item, k2))
    for j in range(item):
        index = item_list1[j]
        H1[j, ] = np.sum(lambda_y[index, ], axis=0)
        H2[j, ] = np.sum(lambda_h[index, ], axis=0)
    H1 = H1 + alpha1; H2 = H2 + beta2

    #ガンマ分布からパラメータをサンプリング
    theta_v = np.random.gamma(H1, 1/H2)

    
    ##コンテキストの特徴行列をサンプリング
    #補助変数lambdaを更新
    mu_dt = np.zeros((hhpt, k3)); lambda_h = np.zeros((hhpt, k3))
    theta_vec2 = theta_v[item_id1, ]
    for j in range(k3):
        lambda_dt = np.dot(theta_u, omega[:, :, j])[d_id1, ] * theta_vec2
        lambda_h[:, j] = np.dot(lambda_dt, vec_k2)
        mu_dt[:, j] = np.dot(lambda_dt * theta_vec3[:, j][:, np.newaxis], vec_k2)
    mu = np.dot(mu_dt, vec_k3)
    Lambda = mu_dt / mu[:, np.newaxis]

    #事後分布のパラメータ
    lambda_y = Lambda * y_vec1
    C1 = np.zeros((context, k3)); C2 = np.zeros((context, k3))
    for j in range(context):
        index = context_list1[j]
        C1[j, ] = np.sum(lambda_y[index, ], axis=0)
        C2[j, ] = np.sum(lambda_h[index, ], axis=0)
    C1 = C1 + alpha3; C2 = C2 + beta3

    #ガンマ分布からパラメータをサンプリング
    theta_c = np.random.gamma(C1, 1/C2)

    
    ##ガンマ分布よりomegaをサンプリング
    #補助変数lambdaを更新
    mu_block = np.zeros((k1, k2, k3))
    theta_dt12 = [j for j in range(k1)]
    for j1 in range(k3):
        theta_dt3 = theta_vec3[:, j1][:, np.newaxis]
        for j2 in range(k1):
            if j1==0:
                theta_dt12[j2] = theta_vec1[:, j2][:, np.newaxis] * theta_vec2
            mu_dt = theta_dt12[j2] * theta_dt3
            mu_block[j2, :, j1] = np.sum(mu_dt, axis=0)
    omega_block = omega * mu_block
    Lambda = omega_block / np.sum(omega_block)

    #ガンマ分布からパラメータをサンプリング
    omega1 = Lambda * np.sum(y1) + alpha4
    omega2 = mu_block + beta4
    omega = np.random.gamma(omega1, 1/omega2)
    

    ##サンプリング結果の格納と表示
    if rp%keep==0:
        mkeep = int(rp/keep)
        THETA_U[:, :, mkeep] = theta_u
        THETA_V[:, :, mkeep] = theta_v
        THETA_C[:, :, mkeep] = theta_c
        OMEGA[:, :, :, mkeep] = omega
        
    if rp%disp==0:
        #学習データに対する対数尤度
        mu = np.repeat(0.0, hhpt)
        theta_vec2 = theta_v[item_id1, ]
        theta_vec3 = theta_c[context_id1, ]
        for j in range(k3):
            mu += np.dot(np.dot(theta_u, omega[:, :, j])[d_id1, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)
        LL1 = np.sum(y1*np.log(mu) - mu - lfactorial_y1)

        #テストデータに対する対数尤度
        mu = np.repeat(0.0, N)
        theta_vec2 = theta_v[item_id2, ]
        theta_vec3 = theta_c[context_id2, ]
        for j in range(k3):
            mu += np.dot(np.dot(theta_u, omega[:, :, j])[d_id2, ] * theta_vec2 * theta_vec3[:, j][:, np.newaxis], vec_k2)
        LL2 = np.sum(y2*np.log(mu) - mu - lfactorial_y2)

        #サンプリング結果を表示
        print(rp)
        print(["学習データの対数尤度:", np.round(LL1, 1), "学習データの真値の対数尤度:", np.round(LLbest1, 1)])
        print(["テストデータの対数尤度:", np.round(LL2, 1), "テストデータの真値の対数尤度:", np.round(LLbest2, 1)])
# Out:
# 0
# ['学習データの対数尤度:', -2289731.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -2021804.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 10
# ['学習データの対数尤度:', -1939757.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1751445.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 20
# ['学習データの対数尤度:', -1905750.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1739292.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 30
# ['学習データの対数尤度:', -1887158.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1736992.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 40
# ['学習データの対数尤度:', -1872444.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1732584.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 50
# ['学習データの対数尤度:', -1859493.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1729776.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 60
# ['学習データの対数尤度:', -1848441.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1726271.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 70
# ['学習データの対数尤度:', -1838109.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1720101.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 80
# ['学習データの対数尤度:', -1829282.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1714708.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 90
# ['学習データの対数尤度:', -1821419.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1711960.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 100
# ['学習データの対数尤度:', -1814715.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707528.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 110
# ['学習データの対数尤度:', -1808676.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704271.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 120
# ['学習データの対数尤度:', -1803227.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704925.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 130
# ['学習データの対数尤度:', -1798342.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704080.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 140
# ['学習データの対数尤度:', -1793712.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1702273.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 150
# ['学習データの対数尤度:', -1789627.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1699384.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 160
# ['学習データの対数尤度:', -1785919.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1698398.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 170
# ['学習データの対数尤度:', -1782340.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1697615.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 180
# ['学習データの対数尤度:', -1778713.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1697040.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 190
# ['学習データの対数尤度:', -1775274.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1699064.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 200
# ['学習データの対数尤度:', -1772009.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1697190.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 210
# ['学習データの対数尤度:', -1768966.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1696116.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 220
# ['学習データの対数尤度:', -1765607.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1695237.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 230
# ['学習データの対数尤度:', -1762717.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1698004.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 240
# ['学習データの対数尤度:', -1760126.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1697340.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 250
# ['学習データの対数尤度:', -1757768.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1698732.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 260
# ['学習データの対数尤度:', -1755301.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1696199.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 270
# ['学習データの対数尤度:', -1753243.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1699506.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 280
# ['学習データの対数尤度:', -1750526.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1699137.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 290
# ['学習データの対数尤度:', -1748454.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701455.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 300
# ['学習データの対数尤度:', -1746159.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1698085.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 310
# ['学習データの対数尤度:', -1744196.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1700150.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 320
# ['学習データの対数尤度:', -1741921.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1695765.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 330
# ['学習データの対数尤度:', -1739900.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1696582.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 340
# ['学習データの対数尤度:', -1737901.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1699589.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 350
# ['学習データの対数尤度:', -1735985.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1697191.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 360
# ['学習データの対数尤度:', -1734104.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1703435.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 370
# ['学習データの対数尤度:', -1732584.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1700108.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 380
# ['学習データの対数尤度:', -1731024.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1695769.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 390
# ['学習データの対数尤度:', -1729461.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1699950.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 400
# ['学習データの対数尤度:', -1727963.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1700652.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 410
# ['学習データの対数尤度:', -1726706.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1699139.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 420
# ['学習データの対数尤度:', -1725511.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1702495.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 430
# ['学習データの対数尤度:', -1724202.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704012.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 440
# ['学習データの対数尤度:', -1723115.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1705739.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 450
# ['学習データの対数尤度:', -1721936.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701536.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 460
# ['学習データの対数尤度:', -1721106.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1702901.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 470
# ['学習データの対数尤度:', -1720421.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1702562.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 480
# ['学習データの対数尤度:', -1719630.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1702645.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 490
# ['学習データの対数尤度:', -1719107.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706993.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 500
# ['学習データの対数尤度:', -1718290.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1705049.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 510
# ['学習データの対数尤度:', -1717285.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706009.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 520
# ['学習データの対数尤度:', -1716721.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1705674.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 530
# ['学習データの対数尤度:', -1715938.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1708173.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 540
# ['学習データの対数尤度:', -1715375.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706634.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 550
# ['学習データの対数尤度:', -1714751.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1708598.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 560
# ['学習データの対数尤度:', -1714598.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1705681.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 570
# ['学習データの対数尤度:', -1713876.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707191.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 580
# ['学習データの対数尤度:', -1713304.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706196.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 590
# ['学習データの対数尤度:', -1712690.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1708763.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 600
# ['学習データの対数尤度:', -1712368.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704484.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 610
# ['学習データの対数尤度:', -1711968.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706951.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 620
# ['学習データの対数尤度:', -1711440.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704361.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 630
# ['学習データの対数尤度:', -1711212.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707628.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 640
# ['学習データの対数尤度:', -1710732.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707846.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 650
# ['学習データの対数尤度:', -1709990.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1708608.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 660
# ['学習データの対数尤度:', -1709796.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1708413.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 670
# ['学習データの対数尤度:', -1709170.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1710803.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 680
# ['学習データの対数尤度:', -1708786.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706958.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 690
# ['学習データの対数尤度:', -1708472.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707805.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 700
# ['学習データの対数尤度:', -1708427.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1709524.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 710
# ['学習データの対数尤度:', -1708421.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707178.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 720
# ['学習データの対数尤度:', -1707878.4, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1709272.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 730
# ['学習データの対数尤度:', -1707687.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1709213.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 740
# ['学習データの対数尤度:', -1707586.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1711376.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 750
# ['学習データの対数尤度:', -1707631.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707058.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 760
# ['学習データの対数尤度:', -1707910.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1705839.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 770
# ['学習データの対数尤度:', -1708060.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1705959.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 780
# ['学習データの対数尤度:', -1707921.6, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1703517.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 790
# ['学習データの対数尤度:', -1707865.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707342.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 800
# ['学習データの対数尤度:', -1707880.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1708109.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 810
# ['学習データの対数尤度:', -1707907.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1710435.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 820
# ['学習データの対数尤度:', -1708010.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1707517.9, 'テストデータの真値の対数尤度:', -1110239.0]
# 830
# ['学習データの対数尤度:', -1707565.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704514.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 840
# ['学習データの対数尤度:', -1707542.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706002.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 850
# ['学習データの対数尤度:', -1707444.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1706177.4, 'テストデータの真値の対数尤度:', -1110239.0]
# 860
# ['学習データの対数尤度:', -1707365.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1708705.5, 'テストデータの真値の対数尤度:', -1110239.0]
# 870
# ['学習データの対数尤度:', -1707332.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1704687.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 880
# ['学習データの対数尤度:', -1707497.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701159.2, 'テストデータの真値の対数尤度:', -1110239.0]
# 890
# ['学習データの対数尤度:', -1707880.9, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701400.7, 'テストデータの真値の対数尤度:', -1110239.0]
# 900
# ['学習データの対数尤度:', -1707905.1, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701523.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 910
# ['学習データの対数尤度:', -1708106.7, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1698437.8, 'テストデータの真値の対数尤度:', -1110239.0]
# 920
# ['学習データの対数尤度:', -1707947.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1702323.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 930
# ['学習データの対数尤度:', -1708086.0, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1702250.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 940
# ['学習データの対数尤度:', -1708008.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701984.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 950
# ['学習データの対数尤度:', -1708097.3, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1703396.1, 'テストデータの真値の対数尤度:', -1110239.0]
# 960
# ['学習データの対数尤度:', -1708517.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1700568.3, 'テストデータの真値の対数尤度:', -1110239.0]
# 970
# ['学習データの対数尤度:', -1708562.2, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701444.6, 'テストデータの真値の対数尤度:', -1110239.0]
# 980
# ['学習データの対数尤度:', -1708721.8, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1701739.0, 'テストデータの真値の対数尤度:', -1110239.0]
# 990
# ['学習データの対数尤度:', -1708737.5, '学習データの真値の対数尤度:', -1813264.8]
# ['テストデータの対数尤度:', -1696791.2, 'テストデータの真値の対数尤度:', -1110239.0]
